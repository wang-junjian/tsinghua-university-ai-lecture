# %% [markdown]
# # AI行业发展：未来以来，隐约可见
#     商汤科技CEO　徐立

# %% [markdown]
# ## 生产力工具
#
# ### 人工智能是什么
# > 人工智能是一种超越常人的生产力工具。
#
# ### 数据
# * 到2035年，人工智能有望推动世界劳动生产率提高40%以上。
# > 这包括大部分没有被人工智能影响的企业、国家和地区。所以那些头部的企业基本上就是劳动力被取代的模式，两个人被一个人干掉。所以我认为未来十年一个最大的问题是做人机融合，就是怎样利用这些人。我们现在看到AI在某些产业已经代替了人类的劳动和工作，那么人类所需要做的是怎样驾驭机器，怎样实现更好的生产率。至于机器有没有情感，在什么阶段能把人全部取代，这不是我们这帮人研究的问题。
# * 到2030年，人工智能将促使全球生产总值增长14%，为世界经济贡献15.7万亿美元的新增产值。
# > 这相当于现在中国和印度生产总值的总和，即是说，用十年的时间就能新造出一个中国和印度。那么这些新增产值从哪来的呢？还是来自于效率机器。所以未来在很多垂直行业，AI将代替更多的人类。
#
# ### 三个阶段
# * 第一阶段：技不如人
#     > 要过了工业的红线，才能达到工业应用的条件。
# * 第二阶段：超越大众
#     > 人的知识可以通过数据标注教给电脑。那么什么样的数据最容易获得呢？就是普罗大众都会的事情。他们具备普通的知识，他们的知识可以通过数据标注传达给电脑，只要有了这些标注的结果，你就可以教计算机学会。
# * 第三阶段：超越专家
#     > `处理数据：百万级可以作为一个训练单元`
#
#     > 可以做服务升级

# %% [markdown]
# ## 技术突破
#
# * 2016年时中国的人工智能专利的数量增长了70%，虽然总数量还是美国领先。另外在泛AI的学术顶会AAAI上，中国发表的论文数量占据31%；具体在视觉这个垂直领域，CVPR论文的中国作者占据40%。
#
# ### 三大要素保障深度学习平台优异性能
# > 深度学习原创平台，叫Parrots。有了这个平台我们可以处理的东西就很多，当时在ImageNet，我们做了超过1000层的深度神经网络。还有超大数据学习，我们有20亿人脸数据同时训练；此外还有复杂关联应用的多模态数据学习。
#
# * 超深网络
# * 超大数据学习
# * 复杂关联学习
#
# ### 什么是深度学习
# > 深度学习，学习的是对事物的刻画。普通的机器学习依赖专家知识，深度学习提供另外的可能性，学的是一种全局表达。这样的学习可以带来很强的对事情的描述。层次越深，复用性越强。
#
# ### 图像生成
# > 给出一段文字描述“这只小鸟有白色的胸部，浅灰色的头部，和黑色的翅膀和尾巴”，计算机可以生成这只鸟。
#
# ![文字生成图像](images/02_generate_images_by_text.png)
#
# ### 衣食住行
# * 衣：用文字可以生成你想要的衣服，只需要一张照片，每天可以随时换衣服。这些都是生成的结果。
# ![](images/02_clothes.png)
# * 食：吃饭当中也有各种各样可以利用计算机视觉的场景。比如说可以识别食物，计算食物的卡路里。
# * 住：比如说人脸识别的闸机，这个已经非常普遍了。另外一个很大的应用场景时无人商店。
# * 行：很容易想到的就算自动驾驶。可能有人说这还遥遥无期，但是在特定的情况下，慢速的自动驾驶很多已经可以应用起来。
# ![](images/02_travel.png)
#
# ### 政策扶持
# * 北京：首都优势
# * 上海："AI@SH"行动
# * 深圳：全面引入
# * 成都："智慧小镇"
# * 香港：科研实力

# %% [markdown]
# ## 智能视觉计算
#
# * 成像
# * 感知
# * 识别
# * 理解
#
# ### 看清
# ![](images/02_see_clearly1.png)
# ![](images/02_see_clearly2.png)
# ![](images/02_see_clearly3.png)
# ![](images/02_see_clearly4.png)
#
# ### 创作
# ![](images/02_creation1.png)
# ![](images/02_creation2.png)
# ![](images/02_creation3.png)
#
# ### 景深
# ![](images/02_image_depth1.png)
# ![](images/02_image_depth2.png)
# ![](images/02_image_depth3.png)
# ![](images/02_image_depth4.png)

# %% [markdown]
# ## 应用场景
#
# * 人脸检测和人脸识别（深圳交通路口）
# ![](images/02_face_recognition.png)
#
# * 模糊－增强
# ![增强公安确认的依据](images/02_blur_enhancement1.png)
# ![修复以前的漫画](images/02_blur_enhancement2.png)
#
# * 人脸对比（深圳，应用于2000万人）
# ![](images/02_face_comparison.png)
#
# * 深圳文博会布控
# ![](images/02_face_recognition2.jpeg)

# %% [markdown]
# ## 现场讨论
#
# * 视频的分析理解和交互是可以做的非常好，目前AR/VR已经做的非常好了，可以做出许多非常好的应用，引领一波发展。
# * 技术创业要三思。
# * 2000年以来在中国投的都是模式，有了钱再去并购技术。
# * 目前的3－5年进入软件的摩尔定律。
# * 行业高速发展，通过技术形成壁垒，留有足够的迭代周期。行业平稳发展，个人或者小公司就没有机会了。
# * 什么叫人才，Top5%才叫人才。如果你几个行业都懂（跨界），那也有可能成为人才。
# * 现在才学视觉技术，5年后可能就错过了这个机会。

# %% [markdown]
# ## 参考资料
#
# * [商汤科技徐立：AI 将在10 年内创造一个印度和中国的总产值](http://www.sohu.com/a/226386942_473283)
